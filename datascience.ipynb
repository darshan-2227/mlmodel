# %% [markdown]
# <a href="https://colab.research.google.com/github/darshan-2227/mlmodel/blob/master/datascience.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import yfinance as yf

# Extracting Tesla stock data
tesla_data = yf.download('TSLA', start='2021-01-01', end='2024-01-01')

# Reset the index
tesla_data.reset_index(inplace=True)

# Save the DataFrame to a file
tesla_data.to_csv('tesla_stock_data.csv', index=False)

# Display the first five rows
print(tesla_data.head())
# Out:
# [*********************100%%**********************]  1 of 1 completed
#         Date        Open        High         Low       Close   Adj Close  \
# 0 2021-01-04  239.820007  248.163330  239.063339  243.256668  243.256668
# 1 2021-01-05  241.220001  246.946671  239.733337  245.036667  245.036667
# 2 2021-01-06  252.830002  258.000000  249.699997  251.993332  251.993332
# 3 2021-01-07  259.209991  272.329987  258.399994  272.013336  272.013336
# 4 2021-01-08  285.333344  294.829987  279.463318  293.339996  293.339996
#
#       Volume
# 0  145914600
# 1   96735600
# 2  134100000
# 3  154496700
# 4  225166500

# %%
import requests
from bs4 import BeautifulSoup

# Fetching Tesla revenue data from website
url = 'https://www.macrotrends.net/stocks/charts/TSLA/tesla/revenue'

try:
    response = requests.get(url)
    response.raise_for_status()  # Raise error for bad status codes
except requests.exceptions.RequestException as e:
    print("Error fetching data:", e)
    # Handle the error gracefully or exit the script

soup = BeautifulSoup(response.text, 'html.parser')

# Find the table containing revenue data
table = soup.find('table', {'class': 'historical_data_table'})

if table:
    # Extracting revenue data
    rows = table.find_all('tr')[1:]

    # Initialize lists to store data
    dates = []
    revenues = []

    # Extracting data from each row
    for row in rows:
        data = row.find_all('td')
        dates.append(data[0].text)
        revenues.append(data[1].text)

    # Creating DataFrame
    tesla_revenue = pd.DataFrame({'Date': dates, 'Revenue': revenues})

    # Display the last five rows
    print(tesla_revenue.tail())
else:
    print("Table not found. Please verify the website structure.")
# Out:
# Error fetching data: 403 Client Error: Forbidden for url: https://www.macrotrends.net/stocks/charts/TSLA/tesla/revenue
# Table not found. Please verify the website structure.

# %%
import yfinance as yf

# Extracting GameStop stock data
gme_data = yf.download('GME', start='2021-01-01', end='2024-01-01')

# Reset the index
gme_data.reset_index(inplace=True)

# Save the DataFrame to a file if needed
# gme_data.to_csv('gme_stock_data.csv', index=False)

# Display the first five rows
print(gme_data.head())
# Out:
# [*********************100%%**********************]  1 of 1 completed
#         Date    Open    High     Low   Close  Adj Close    Volume
# 0 2021-01-04  4.7500  4.7750  4.2875  4.3125     4.3125  40090000
# 1 2021-01-05  4.3375  4.5200  4.3075  4.3425     4.3425  19846000
# 2 2021-01-06  4.3350  4.7450  4.3325  4.5900     4.5900  24224800
# 3 2021-01-07  4.6175  4.8625  4.5050  4.5200     4.5200  24517200
# 4 2021-01-08  4.5450  4.5750  4.2700  4.4225     4.4225  25928000

# %%
import requests
from bs4 import BeautifulSoup

# Fetching GameStop revenue data from website
url = 'https://www.macrotrends.net/stocks/charts/GME/gamestop/revenue'

try:
    response = requests.get(url)
    response.raise_for_status()  # Raise error for bad status codes
except requests.exceptions.RequestException as e:
    print("Error fetching data:", e)
    # Handle the error gracefully or exit the script

soup = BeautifulSoup(response.text, 'html.parser')

# Find the table containing revenue data
table = soup.find('table', {'class': 'historical_data_table'})

if table:
    # Extracting revenue data
    rows = table.find_all('tr')[1:]

    # Initialize lists to store data
    dates = []
    revenues = []

    # Extracting data from each row
    for row in rows:
        data = row.find_all('td')
        dates.append(data[0].text)
        revenues.append(data[1].text)

    # Creating DataFrame
    gme_revenue = pd.DataFrame({'Date': dates, 'Revenue': revenues})

    # Display the last five rows
    print(gme_revenue.tail())
else:
    print("Table not found. Please verify the website structure.")
# Out:
# Error fetching data: 403 Client Error: Forbidden for url: https://www.macrotrends.net/stocks/charts/GME/gamestop/revenue
# Table not found. Please verify the website structure.

# %%
import matplotlib.pyplot as plt

# Define the make_graph function
def make_graph(data, title):
    plt.figure(figsize=(10, 6))
    plt.plot(data['Date'], data['Close'])
    plt.title(title)
    plt.xlabel('Date')
    plt.ylabel('Closing Price ($)')
    plt.grid(True)
    plt.show()

# Call the make_graph function for Tesla stock data
make_graph(tesla_data, 'Tesla Stock Closing Prices')

# %%
import matplotlib.pyplot as plt

# Define the make_graph function
def make_graph(data, title):
    plt.figure(figsize=(10, 6))
    plt.plot(data['Date'], data['Close'])
    plt.title(title)
    plt.xlabel('Date')
    plt.ylabel('Closing Price ($)')
    plt.grid(True)
    plt.show()

# Call the make_graph function for GameStop stock data
make_graph(gme_data, 'GameStop Stock Closing Prices')
